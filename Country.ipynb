# %%
import pandas as pd
data = pd.read_excel('Height of Male and Female by Country.xlsx')
data
# Out:
#      Rank            Country Name  Male Height in Cm  Female Height in Cm  \
# 0       1             Netherlands             183.78               170.36
# 1       2              Montenegro             183.30               169.96
# 2       3                 Estonia             182.79               168.66
# 3       4  Bosnia and Herzegovina             182.47               167.47
# 4       5                 Iceland             182.10               168.91
# ..    ...                     ...                ...                  ...
# 194   195              Mozambique             164.30               155.42
# 195   196        Papua New Guinea             163.10               156.89
# 196   197         Solomon Islands             163.07               156.79
# 197   198                    Laos             162.78               153.10
# 198   199             Timor-Leste             160.13               152.71
#
#      Male Height in Ft  Female Height in Ft
# ...

# %%
data.shape
# Out:
# (199, 6)

# %%
data.head()
# Out:
#    Rank            Country Name  Male Height in Cm  Female Height in Cm  \
# 0     1             Netherlands             183.78               170.36
# 1     2              Montenegro             183.30               169.96
# 2     3                 Estonia             182.79               168.66
# 3     4  Bosnia and Herzegovina             182.47               167.47
# 4     5                 Iceland             182.10               168.91
#
#    Male Height in Ft  Female Height in Ft
# 0               6.03                 5.59
# 1               6.01                 5.58
# 2               6.00                 5.53
# 3               5.99                 5.49
# 4               5.97                 5.54

# %%
data.tail()
# Out:
#      Rank      Country Name  Male Height in Cm  Female Height in Cm  \
# 194   195        Mozambique             164.30               155.42
# 195   196  Papua New Guinea             163.10               156.89
# 196   197   Solomon Islands             163.07               156.79
# 197   198              Laos             162.78               153.10
# 198   199       Timor-Leste             160.13               152.71
#
#      Male Height in Ft  Female Height in Ft
# 194               5.39                 5.10
# 195               5.35                 5.15
# 196               5.35                 5.14
# 197               5.34                 5.02
# 198               5.25                 5.01

# %%
data.dtypes
# Out:
# Rank                     int64
# Country Name            object
# Male Height in Cm      float64
# Female Height in Cm    float64
# Male Height in Ft      float64
# Female Height in Ft    float64
# dtype: object

# %%
data.columns
# Out:
# Index(['Rank', 'Country Name', 'Male Height in Cm', 'Female Height in Cm',
#        'Male Height in Ft', 'Female Height in Ft'],
#       dtype='object')

# %%
data.head(3)
# Out:
#    Rank Country Name  Male Height in Cm  Female Height in Cm  \
# 0     1  Netherlands             183.78               170.36
# 1     2   Montenegro             183.30               169.96
# 2     3      Estonia             182.79               168.66
#
#    Male Height in Ft  Female Height in Ft
# 0               6.03                 5.59
# 1               6.01                 5.58
# 2               6.00                 5.53

# %%
data.tail(8)
# Out:
#      Rank      Country Name  Male Height in Cm  Female Height in Cm  \
# 191   192             Yemen             164.42               154.76
# 192   193             Nepal             164.36               152.39
# 193   194         Guatemala             164.36               150.91
# 194   195        Mozambique             164.30               155.42
# 195   196  Papua New Guinea             163.10               156.89
# 196   197   Solomon Islands             163.07               156.79
# 197   198              Laos             162.78               153.10
# 198   199       Timor-Leste             160.13               152.71
#
#      Male Height in Ft  Female Height in Ft
# 191               5.39                 5.08
# 192               5.39                 5.00
# 193               5.39                 4.95
# 194               5.39                 5.10
# 195               5.35                 5.15
# 196               5.35                 5.14
# ...

# %%
data.tail(20)
# Out:
#      Rank      Country Name  Male Height in Cm  Female Height in Cm  \
# 179   180      Sierra Leone             166.43               157.34
# 180   181            Brunei             166.31               154.90
# 181   182         Indonesia             166.26               154.36
# 182   183            Rwanda             166.02               156.72
# 183   184            Malawi             165.68               156.14
# 184   185        Mauritania             165.54               160.06
# 185   186           Liberia             165.48               156.54
# 186   187          Cambodia             165.35               154.75
# 187   188  Marshall Islands             165.26               154.76
# 188   189       Philippines             165.23               154.14
# 189   190        Madagascar             165.16               153.06
# 190   191        Bangladesh             165.08               152.38
# 191   192             Yemen             164.42               154.76
# ...

# %%
data.head(20)
# Out:
#     Rank            Country Name  Male Height in Cm  Female Height in Cm  \
# 0      1             Netherlands             183.78               170.36
# 1      2              Montenegro             183.30               169.96
# 2      3                 Estonia             182.79               168.66
# 3      4  Bosnia and Herzegovina             182.47               167.47
# 4      5                 Iceland             182.10               168.91
# 5      6                 Denmark             181.89               169.47
# 6      7          Czech Republic             181.19               167.96
# 7      8                  Latvia             181.17               168.81
# 8      9                Slovakia             181.02               167.12
# 9     10                Slovenia             180.98               167.20
# 10    11                 Ukraine             180.98               166.62
# 11    12                 Croatia             180.76               166.80
# ...

# %%
data.head(30)
# Out:
#     Rank            Country Name  Male Height in Cm  Female Height in Cm  \
# 0      1             Netherlands             183.78               170.36
# 1      2              Montenegro             183.30               169.96
# 2      3                 Estonia             182.79               168.66
# 3      4  Bosnia and Herzegovina             182.47               167.47
# 4      5                 Iceland             182.10               168.91
# 5      6                 Denmark             181.89               169.47
# 6      7          Czech Republic             181.19               167.96
# 7      8                  Latvia             181.17               168.81
# 8      9                Slovakia             181.02               167.12
# 9     10                Slovenia             180.98               167.20
# 10    11                 Ukraine             180.98               166.62
# 11    12                 Croatia             180.76               166.80
# ...
